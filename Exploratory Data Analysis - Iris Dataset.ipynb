# %% [markdown]
# The Irish dataset is one of the well known multivariate (multipe variable) dataset used in Data Science and for various Machine Learning Algorithms
#
# This my version of EDA on Iris dataset
#
# Every visualization step is detail Data insights.

# %% [markdown]
# ## Import Libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %%
iris_data = pd.read_csv('iris.csv')

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Information from dataset

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### DATA INSIGHT
#
# 1 All columns are not having Null (empty) entry i.e. no missing value
#
# 2 Four columns are numerical data type
#
# 3 One column is categorical type (string or object datatype) of different species
#
# 4 There are a total of five columns in the dataset
#
# 5 There are a total of 150 data entries in the dataset

# %% [markdown]
# ## Statistical Insight

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### DATA INSIGHT
#
# 1 Mean values
#
# 2 Standard Deviation
#
# 3 Minimum values
#
# 4 Maximum values
#
# 5 Quartiles (1st, 2nd and 3rd)

# %% [markdown]
# ## Check for Duplicate Entries

# %%
iris_data[iris_data.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %% [markdown]
# There is only one duplicate, therefore let's check whether each specie in the dataset has equal entries

# %%
iris_data['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# The dataset contains three species of balanced entries of 50. Therefore the is no need to delete the entry as it might unbalance the dataset and hence prove to be less useful for valuable insights

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Species count

# %%
plt.title('Species Count')
sns.countplot(iris_data['species'])
# Out:
# <AxesSubplot:title={'center':'Species Count'}, xlabel='species', ylabel='count'>

# %%
sns.countplot(x='species',data=iris_data).set_title('Species Count')
# Out:
# Text(0.5, 1.0, 'Species Count')

# %% [markdown]
# #### Data Insights:
#
# 1 This visual further confirms that species are well balanced
#
# 2 Each species of Iris flower (Setosa, Versicolor, Virginica) has 50 as it's count

# %% [markdown]
# ## Uni-variate Analysis
#
# #### Comparison between various species based on sepal length and width

# %%
plt.figure(figsize=(17,9))
plt.title('Comparison between various species based on sepal length and width')
sns.scatterplot(iris_data['sepal_length'], iris_data['sepal_width'], hue=iris_data['species'], s=50)
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on sepal length and width'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# #### Data Insights:
#
# 1 Setosa species have higer sepal width but smaller sepal length.
#
# 2 Versicolor species have almost an average sepal width and sepal length.
#
# 3 Virhinica species have smaller sepal width and higher length

# %% [markdown]
# ### Comparison between various species based on petal width and length

# %%
plt.figure(figsize=(17,9))
plt.title('Comparison between various species based on petal width and length')
sns.scatterplot(iris_data['petal_length'], iris_data['petal_width'], hue=iris_data['species'], s=50)
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on petal width and length'}, xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# #### Data Insights:
#
# 1 Setosa species have the smallest petal width and petal length.
#
# 2 Versicolor species have average petal width and petal length.
#
# 3 Virginica species have highest petal width and petal length.

# %% [markdown]
# ## Bi-variate Analysis

# %%
sns.pairplot(iris_data, hue="species", height=4)

# %% [markdown]
# #### Data Insights:
#
# 1 High correlation between petal lenght and width column.
#
# 2 Setosa has both low petal length and width.
#
# 3 Versicolor has both average petal length and width.
#
# 4 Virginica has both large petal length and width.
#
# 5 Setosa has high sepal width and small sepal length.
#
# 6 Versicolor has average values for sepal dimension.
#
# 7 Virginica has small sepal width but high sepal length.

# %% [markdown]
# ## Checking Correlation

# %%
plt.figure(figsize=(10,11))
sns.heatmap(iris_data.corr(), annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# #### Data Insights:
#
# 1 Sepal length and sepal width features are slightly correlated with each other.

# %% [markdown]
# ## Checking Mean & Median Values for each species

# %%
iris_data.groupby('species').agg(['mean','median'])
# Out:
#            sepal_length        sepal_width        petal_length         \
#                    mean median        mean median         mean median
# species
# setosa            5.006    5.0       3.428    3.4        1.462   1.50
# versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#            petal_width
#                   mean median
# species
# setosa           0.246    0.2
# versicolor       1.326    1.3
# virginica        2.026    2.0

# %% [markdown]
# visualizing the distribution, mean and median using boxplots & violin plots

# %% [markdown]
# ## Box plots to know about distribution
# boxplot to see how the categorical feature "species" is distributed with all other four input variable.

# %%
fig,axes=plt.subplots(2,2,figsize=(16,9))
sns.boxplot(y='petal_width', x='species',data=iris_data,orient='v',ax=axes[0,0])
sns.boxplot(y='petal_length',x='species',data=iris_data,orient='v',ax=axes[0,1])
sns.boxplot(y='sepal_length',x='species',data=iris_data, orient='v',ax=axes[1,0])
sns.boxplot(y='sepal_width',x='species',data=iris_data, orient='v',ax=axes[1,1])
plt.show()

# %% [markdown]
# #### Data Insights:
#
# 1 Setosa have smaller features and less distribution.
#
# 2 Versicolor have an average distribution and average features.
#
# 3 Virginica is highly distributed with large number of values and features.
#
# 4 Clearly the mean/median values are being shown by each plots for various features (sepal length & width, petal length & width)

# %% [markdown]
# ## Violin Plot for Checking Distribution
# The violin plot shows density of the length and width in the species. The thinner part denotes that there is less density whereas the fatter part conveys higher density

# %%
fig,axes=plt.subplots(2,2,figsize=(16,10))
sns.violinplot(y='petal_width',x='species',data=iris_data,orient='v',ax=axes[0,0],inner='quartile')
sns.violinplot(y='petal_length',x='species',data=iris_data,orient='v',ax=axes[0,1],inner='quartile')
sns.violinplot(y='sepal_length',x='species',data=iris_data,orient='v',ax=axes[1,0],inner='quartile')
sns.violinplot(y='sepal_width',x='species',data=iris_data,orient='v',ax=axes[1,1],inner='quartile')
plt.show()

# %% [markdown]
# #### Data Insights:
#
# 1 Setosa have less distribution and density in case of petal length & width.
#
# 2 Versicolor is distributed in an average manner and average features in the case of petal length & width.
#
# 3 Virginica is highly distributed with large number of values and features in case of sepal length & width.
#
# 4 High density values are depicting the mean/median values, for example iris setosa has highest density at 5.0cm (sepal length features) which also the median value of (5.0) as per the table.

# %% [markdown]
# ## Plotting the Histogram & Probability Density Function (PDF)
# plotting the probability density function (PDF) with each feature as a variable on X-axis and it's histogram and corresponding kernel density plot on Y-axis

# %%
sns.FacetGrid(iris_data, hue="species", height=5)\
.map(sns.distplot,'sepal_length')\
.add_legend()

sns.FacetGrid(iris_data,hue='species',height=5)\
.map(sns.distplot,'sepal_width')\
.add_legend()

sns.FacetGrid(iris_data,hue='species',height=5)\
.map(sns.distplot,'petal_length')\
.add_legend()

sns.FacetGrid(iris_data,hue='species',height=5)\
.map(sns.distplot,'petal_width')\
.add_legend()

# %% [markdown]
# #### Data Insights:
#
# 1 Plot 1 shows that there is a significant amount of overlap between the species on sepal length, so it is not an effective classification feature.
#
# 2 Plot 2 shows that ther is even higher overlap between the species on sepal width, therefore it is not an effective classification feature.
#
# 3 Plot 3 shows that petal length is a good classification feature as it clearly separates the species. The overlap is very minimal between Versicolor and Virginica, while Setosa is well separated from the two.
#
# 4 Plot 4 just like Plot 3 shows that petal width is a classification feature as it clearly separates the species. The overlap is very minimal between Versicolor and Virginica, while Setosa is well separated from the two.

# %% [markdown]
# ## Choosing Plot 3 (Classification feature as petal length) to distiquish among species.

# %% [markdown]
# #### Data Insights:
#
# 1 The PDF curve of Setosa ends roughly at 2.2
#
# 2 If petal length is less than 2.1, then the specie is Setosa
#
# 3 The point of intersection between PDF curves of Versicolor and Virginica is roughly 4.8
#
# 4 If petal length is greater than 2.2 and less than 4.8 (2.2<petal_length<4.8), then the specie is Versicolor.
#
# 5 If petal length is greater than 4.8, then the specie is Virginica.

# %% [markdown]
# ## Future Work
# Application of machine learning classification algorithms for predicting the species.
